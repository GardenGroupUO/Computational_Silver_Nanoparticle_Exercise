# %% [markdown]
# # Part 2.2: How do nanoparticles and molecules Differ?
#
# When you say the word "chemistry", what do you think about. Maybe you think about atoms, maybe you think about molecules, maybe you now think about nanoparticles. But how does the size of nanoparticles compare with the size of molecules that we maybe more familiar with. In this section, we will look at some simple molecules and compared their size and what they look like with nanoparticles from our Part 2.1 exercise.

# %% [markdown]
# To begin, first **load the prerequisite files**.

# %%
#@markdown <font color="black" size="+2">←</font><font color="red" size="+1"> **Click the play button to load our prerequisite files**</font>

# !echo --------------------------------
# !echo Installing python programs
# !pip install ase==3.22.0 &> /dev/nul
# !echo Completed installing python programs
# !if [ -d Computational_Silver_Nanoparticle_Exercise_Data ]; then rm -Rf Computational_Silver_Nanoparticle_Exercise_Data; fi
# !echo --------------------------------
# !echo Downloading background python scripts from github
# !git clone https://github.com/GardenGroupUO/Computational_Silver_Nanoparticle_Exercise_Data &> /dev/nul
# !echo Completed downloading background python scripts from github
# !echo --------------------------------

# %% [markdown]
# We are going to look at what some simple molecules look like. You have four choices of molecules to look at. **These are H<sub>2</sub>O, NaCl, CH<sub>3</sub>CH<sub>2</sub>OCH<sub>3</sub>, and SiH<sub>3</sub>CH<sub>3</sub>**.
#
# To choose one of these molecules to look at, **write into the variable called ``molecule_name`` either ``'H2O'``, ``'NaCl'``, ``'CH3CH2OCH3'``, or ``'CH3SiH3'``**, and then **press the <img src="https://github.com/GardenGroupUO/Computational_Silver_Nanoparticle_Exercise_Data/blob/main/Images/stop_images/playsvg.png?raw=true" alt="drawing" width="28"/> button** to change the molecule you want to look at
#
# **Use the following code to help you answer the questions below**

# %%
import os
if not os.path.exists('/content/Computational_Silver_Nanoparticle_Exercise_Data'):
    message = 'Could not load files. Make sure you have run the prerequisites before running this code.'
    tostring =  '\n'+'-'*len(message)+'\n'
    tostring += message+'\n'
    tostring += '-'*len(message)
    raise Exception(tostring)

from Computational_Silver_Nanoparticle_Exercise_Data.make_molecule import make_molecule
from Computational_Silver_Nanoparticle_Exercise_Data.viewer.x3d_viewer import view_x3d

molecule_name = 'CH3CH2OCH3' #Enter into this variable one of the following and then rerun this code by clicking the play button to change the molecule you want to look at: 'H2O', 'NaCl', 'CH3CH2OCH3', 'CH3SiH3'
atoms = make_molecule(molecule_name)

view_x3d(atoms,'Exercise_2.2')

# %% [markdown]
# >Q1: What is the longest distance between atoms in H<sub>2</sub>O in Angstrom (Å) ?
#
# >A1: Write your answer here

# %% [markdown]
# >Q2: What is the longest distance between atoms in NaCl in Angstrom (Å) ? (The distance between the Na and Cl atom)
#
# >A2: Write your answer here

# %% [markdown]
# >Q3: What is the longest distance between atoms in CH<sub>3</sub>CH<sub>2</sub>OCH<sub>3</sub> in Angstrom (Å) ? (Hint: You will want to measure the distance between the two hydrogen atoms that are furthest away from each other)
#
# >A3: Write your answer here

# %% [markdown]
# **Some other questions:**

# %% [markdown]
# >Q4: Go back to your Part 2.1 tab and write here what the diameter of a nanoparticle that contained 21,127 atoms was (Part 2.1, Q4)
#
# >A4:

# %% [markdown]
# >Q5: Which is bigger, this 21,127 atom nanoparticle, or the molecules you have look at here?
#
# >A5:

# %% [markdown]
# >Q6: How many times bigger or smaller is a nanoparticle containing 21,127 atoms compare to a water molecule?
#
# >A6:

# %% [markdown]
# If you want to take a look at some other funky molecules and crystals for a bit of fun, take a look at some of the examples at http://www.openmx-square.org/viewer/.
#
# When you are ready to move on, first **CLOSE ALL THE Google Colab TABS YOU HAVE OPEN**, then move on to **Part_2.3_Faces_of_a_Nanoparticle.ipynb**.
