# %% [markdown]
# # **Part 2.2: How do nanoparticles and molecules differ?**
#
# When you say the word "chemistry", what do you think about? Maybe you think about atoms, maybe you think about molecules, maybe you now think about nanoparticles. But how does the size of nanoparticles compare with the size of molecules that we may be more familiar with?
#
# In this section, we will look at some simple molecules and compare their size and what they look like with nanoparticles from our Part 2.1 exercise.
#
# To begin, first <font color="195EBC" size="">**load the prerequisite files**.</font>

# %%
#@markdown <font color="black" size="+2">←</font><font color="red" size="+1"> **Click the play button to load our prerequisite files**</font>

# !echo --------------------------------
# !echo Installing python programs
# !pip install ase==3.22.0 &> /dev/nul
# !echo Completed installing python programs
# !if [ -d Computational_Silver_Nanoparticle_Exercise_Data ]; then rm -Rf Computational_Silver_Nanoparticle_Exercise_Data; fi
# !echo --------------------------------
# !echo Downloading background python scripts from github
# !git clone https://github.com/GardenGroupUO/Computational_Silver_Nanoparticle_Exercise_Data &> /dev/nul
# !echo Completed downloading background python scripts from github
# !echo --------------------------------
# Out:
# --------------------------------
# Installing python programs
# Completed installing python programs
# --------------------------------
# ...
# Completed downloading background python scripts from github
# --------------------------------

# %% [markdown]
# We are going to look at what some simple molecules look like. You have four choices of molecules to look at. <font color="195EBC" size="">**These are H<sub>2</sub>O, HCl, CH<sub>3</sub>CH<sub>2</sub>OCH<sub>3</sub>, and CH<sub>3</sub>SiH<sub>3</sub>**.</font>
#
# To choose one of these molecules to look at, <font color="195EBC" size="">**edit the code below and write into the variable called </font> ``molecule_name`` <font color="195EBC" size="">either</font> ``'H2O'``, ``'HCl'``, ``'CH3CH2OCH3'``, <font color="195EBC" size="">or </font> ``'CH3SiH3'``**,</font> and then <font color="195EBC" size="">**press the <img src="https://github.com/GardenGroupUO/Computational_Silver_Nanoparticle_Exercise_Data/blob/main/Images/stop_images/playsvg.png?raw=true" alt="drawing" width="28"/> button**</font> to change the molecule you want to look at
#
# <font color="195EBC" size="">**Use the following code to help you answer the questions below**</font>

# %%
import os
if not os.path.exists('/content/Computational_Silver_Nanoparticle_Exercise_Data'):
    message = 'Could not load files. Make sure you have run the prerequisites before running this code.'
    tostring =  '\n'+'-'*len(message)+'\n'
    tostring += message+'\n'
    tostring += '-'*len(message)
    raise Exception(tostring)

from Computational_Silver_Nanoparticle_Exercise_Data.make_molecule import make_molecule
from Computational_Silver_Nanoparticle_Exercise_Data.viewer.x3d_viewer import view_x3d

molecule_name = 'CH3CH2OCH3' #Enter into this variable one of the following and then rerun this code by clicking the play button to change the molecule you want to look at: 'H2O', 'HCl', 'CH3CH2OCH3', 'CH3SiH3'
atoms = make_molecule(molecule_name)

view_x3d(atoms,'Exercise_2.2')
# Out:
# <!DOCTYPE>
# <html>
# <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
#     <title>Chemistry Outreach Chemistry Viewer</title>
#     <script type="text/javascript" src="https://www.x3dom.org/download/x3dom.js"> </script>
#     <link rel="stylesheet" type="text/css" href="https://www.x3dom.org/download/x3dom.css"/>
#     <script type="text/javascript" src="https://code.jquery.com/jquery-2.1.0.min.js" ></script>
#
#     <script>
#         //Viewing functions
#
#         function move_view(viewpoint_id)
#         {
#             var viewpoint = document.getElementById(viewpoint_id)
#
#             var viewpoint_id_1 = viewpoint_id+'_1'
#             var viewpoint_id_2 = viewpoint_id+'_2'
#
#             var centerOfRotation = document.getElementById(viewpoint_id_1).getAttribute("centerOfRotation")
#             var last_pressed = document.getElementById(viewpoint_id_1).getAttribute("last_pressed")
#
#             if(last_pressed=='false'){
# ...

# %% [markdown]
# >Q1: What is the longest distance between atoms in **<font color="195EBC" size="">H<sub>2</sub>O</font>** in Angstrom (Å) ?
#
# >A1: Å

# %% [markdown]
# >Q2: What is the longest distance between atoms in <font color="195EBC" size="">**HCl**</font> in Angstrom (Å) ? (The distance between the H and Cl atom)
#
# >A2: Å

# %% [markdown]
# >Q3: What is the longest distance between atoms in **<font color="195EBC" size="">CH<sub>3</sub>CH<sub>2</sub>OCH<sub>3</sub></font>** in Angstrom (Å) ? *(Hint: You will want to measure the distance between the two hydrogen atoms that are furthest away from each other)*
#
# >A3: Å

# %% [markdown]
# **Some other questions:**

# %% [markdown]
# >Q4: Go back to your Part 2.1 tab and write here the diameter of a nanoparticle that contained 21,127 atoms **<font color="195EBC" size="">(Part 2.1, Q4)</font>**
#
# >A4: Å

# %% [markdown]
# >Q5: Which is bigger, this 21,127 atom nanoparticle, or the molecules you have looked at here?
#
# >A5:

# %% [markdown]
# >Q6: How many times bigger or smaller is a nanoparticle containing 21,127 atoms compared to a water molecule?
#
# >A6:

# %% [markdown]
# When you are ready to move on, first <font color="195EBC" size="">**SAVE (Windows: Ctrl+s/Mac:** <img src="https://github.com/GardenGroupUO/Computational_Silver_Nanoparticle_Exercise_Data/blob/main/Images/Part_1.0/command_mac.png?raw=true" alt="drawing" width="14"/>**+s) AND CLOSE ALL THE Google Colab TABS YOU HAVE OPEN**,</font> then move on to <font color="195EBC" size="">**Part_2.3_Faces_of_a_Nanoparticle.ipynb**.</font>
#
# # **Extra for experts!**
#
# If you want to take a look at some other molecules and crystals for a bit of fun, take a look at some of the examples at http://www.openmx-square.org/viewer/. In the box at the bottom right that says "Examples" you can select a range of other molecules and crystals. You might recognise some of these (e.g. buckyballs, DNA) but others are quite exotic!
