# %% [markdown]
# # Online Computational Nanochemistry Worksheet
#
# Nanotechnology is a branch of chemistry that is being used in many applications to solves major problems in the world. For examples:
#
# - In medicine, nanoparticles are used in drug delivery and in contrast agents in MRI machines.
# - In cosmetics, titanium oxide nanoparticles are use in sunscreens to protect your skin from UV light.
# - In light applications and in are, metallic nanoparticles are used because their colour can be controlled by their size and shape.
#
# In this worksheet, we will learn what nanoparticles are, what they look like and what determines their shape, and why nanoparticles of different sizes have different colours.
#
# This worksheet has three parts:
#
# - Part 1: Getting Started - In this section, we will learn some basics of computer programming in a programming language called "Python". We will also learn about to use these "Jupyter" worksheets which we will use for running our python programs, and the atomic simulation environment module that we will use to make our nanoparticles.
#
# - Part 2: Nanoparticles - In this section, we will learn what a nanoparticle is and what gives a nanoparticle its shape.
#
# - Part 3: Silver Nanoprisms - In this section, we will learn about silver nanoparticles and how nanoparticles of different sizes have different colours.

# %% [markdown]
# **IMPORTANT NOTE IF YOU ARE RUNNING THIS ON GOOGLE COLAB:** You MUST run the code below to install some of the packages that are needed for this notebook to run on Google Colab

# %%
# !pip install ase==3.22.0 nglview==1.1.6 ase-notebook==0.3.2 jupyter-client==6.1.11 jupyter-console==6.4.0 jupyter-core==4.7.0 jupyter-server==1.2.0 jupyterlab==3.0.5 jupyterlab-pygments==0.1.2 jupyterlab-server==2.1.2 jupyterlab-widgets==1.0.0 ipydatawidgets==4.2.0 ipykernel==5.5.5 ipython==7.19.0 ipython-genutils==0.2.0 ipywidgets==7.6.3 nbclassic==0.2.6 nbclient==0.5.1 nbconvert==6.0.7 nbformat==5.1.3

# %% [markdown]
# **To begin, click on Part 1.1: Python3 and Jupyter**. You can also click on any of the other links to go straight to that exercise.

# %% [markdown]
# ## Part 1: Getting Started
#
# [1. Python3 and Jupyter](./Part_1_Getting_Started/1_Python3_and_Jupyter.ipynb)
#
# [2. Using ASE](./Part_1_Getting_Started/2_ASE.ipynb)
#
# ## Part 2: Nanoparticles
#
# [1. What are Nanoparticles?](./Part_2_Nanoparticles/1_What_are_Nanoparticles.ipynb)
#
# [2. How do Nanoparticles and Molecules Differ?](./Part_2_Nanoparticles/2_Nanoparticles_and_Molecules.ipynb)
#
# [3. What are the Faces on the Surface of a Nanoparticle?](./Part_2_Nanoparticles/3_Faces_of_a_Nanoparticle.ipynb)
#
# [4. How are these Faces related to Energetics and Stability?](./Part_2_Nanoparticles/4_Faces_related_to_Energy_and_Stability.ipynb)
#
# [5. How do Metallic Nanoparticles Differ?](./Part_2_Nanoparticles/5_Types_of_Metal_Nanoparticles.ipynb)
#
# ## Part 3: Silver Nanoprisms
#
# [1. What do the Silver Nanoprisms look like?](./Part_3_Silver_Nanoparticles/1_Appearance_of_Ag_Nanoparticles.ipynb)
#
# [2. Why do different size Nanoprisms have different Colours?](./Part_3_Silver_Nanoparticles/2_Silver_Nanoparticles_and_Colour.ipynb)
#
# [3. How are Nanoprisms made with different Sizes?](./Part_3_Silver_Nanoparticles/3_Shapes_of_Ag_Nanoparticles.ipynb)
