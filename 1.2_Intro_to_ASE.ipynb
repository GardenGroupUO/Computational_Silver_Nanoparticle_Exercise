# %% [markdown]
# # 1.2: Using Python and the Atomic Simulation Environment (ASE)

# %% [markdown]
# For the activities we will be learning about today, we will be using a python program called **Atomic Simulation Environment (ASE)**. ASE is a set of tools written in Python3 that allows us the construct, manipulate, and analyse molecules and nanoparticles that we make today.
#
# ## Before we being: Prerequisites
#
# Make sure that you first load all the files we need

# %%
#@markdown <font color="black" size="+1">←</font><font color="black" size="+1"> Click the $\blacktriangleright$ play button to load our files</font>

# !pip install ase==3.22.0 nglview==1.1.6 ase-notebook==0.3.2 jupyter-client==6.1.11 jupyter-console==6.4.0 jupyter-core==4.7.0 jupyter-server==1.2.0 jupyterlab==3.0.5 jupyterlab-pygments==0.1.2 jupyterlab-server==2.1.2 jupyterlab-widgets==1.0.0 ipydatawidgets==4.2.0 ipykernel==5.5.5 ipython==7.19.0 ipython-genutils==0.2.0 ipywidgets==7.6.3 nbclassic==0.2.6 nbclient==0.5.1 nbconvert==6.0.7 nbformat==5.1.3 &> /dev/nul
# !git clone https://github.com/GardenGroupUO/Computational_Silver_Nanoparticle_Exercise_Data &> /dev/nul

# %% [markdown]
# Excellent, lets get cracking!
#
# ## Having a play with ASE
#
# To see how ASE works, we are going to use it to make a silver nanoparticle that we can then view. To do this, run the code below by pressing on the $\blacktriangleright$ play button. Hopefully, you will see a silver nanoparticle once it has run.

# %%
from google.colab import output
output.enable_custom_widget_manager()

from Computational_Silver_Nanoparticle_Exercise_Data.viewer import viewer

from ase.cluster import wulff_construction

symbol = 'Ag'
surf_e_100 = 1.1808             
surf_e_111 = 1.0
esurf = [surf_e_100,surf_e_111]
surfaces = [(1,0,0),(1,1,1)]
size = 500

atoms = wulff_construction(symbol,surfaces,esurf,size,'fcc',rounding='above')

vr = viewer(atoms)
vr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fdfffae036bb> in <module>()
#       2 output.enable_custom_widget_manager()
#       3
# ----> 4 from Computational_Silver_Nanoparticle_Exercise_Data.viewer import viewer
#       5
#       6 from ase.cluster import wulff_construction
#
# /content/Computational_Silver_Nanoparticle_Exercise_Data/viewer.py in <module>()
#      27         return v
#      28
# ---> 29 vr = viewer(atoms)
#      30 #import pdb; pdb.set_trace()
#
# NameError: name 'atoms' is not defined

# %% [markdown]
# Have a play around with the nanoparticle in th e

# %%
# !pip install widget_jsmol

# !pip install widget_periodictable

# !pip install jupyter_jsmol
# Out:
# ...
#      |████████████████████████████████| 459 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 547 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 7.4 MB 5.3 MB/s
# ...

# %%
from google.colab import output
output.enable_custom_widget_manager()

from ase.cluster import wulff_construction

symbol = 'Ag'
surf_e_100 = 1.1808             
surf_e_111 = 1.0
esurf = [surf_e_100,surf_e_111]
surfaces = [(1,0,0),(1,1,1)]
size = 500

atoms = wulff_construction(symbol,surfaces,esurf,size,'fcc',rounding='above')

from jupyter_jsmol import JsmolView
from ipywidgets import Layout, widgets, interact

view2 = JsmolView.from_ase(atoms)
display(view2)


view2.fullscreen()
# Out:
# JsmolView(layout=Layout(align_self='stretch', height='400px'))
