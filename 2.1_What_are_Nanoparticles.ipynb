# %% [markdown]
# [Previous Page: 1.2: Using ASE](../Part_1_Getting_Started/2_ASE.ipynb) | [Next Page: 2.2: How do Nanoparticles and Molecules Differ?](./2_Nanoparticles_and_Molecules.ipynb) | [Return to Table of Contents](../Title_Page.ipynb)
#
# # 2.1: What are Nanoparticles?

# %% [markdown]
# A nanoparticle is a set of atoms that are clumped together. Nanoparticles are nanoscale, meaning that they are 20,000 times smaller than the width of a human hair.

# %% [markdown]
# To begin our computational exercises, we will inspect the sizes that nanoparticles can take by creating various nanoparticles virtually on the computer.
#
# Run the python program below by clicking on this line of code that begins with ``from size import make_nanoparticle`` and press the $\blacktriangleright$ button in the menu bar above.
#
# The program will then ask you how many atoms you would like in your nanoparticle. The most stable nanoparticle that contains either the exact number of atoms specified or as close to that number of atoms as possible will be shown. **To begin, type 500 into the input**.

# %%
from size import make_nanoparticle
make_nanoparticle()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d30bbddefa94> in <module>()
# ----> 1 from size import make_nanoparticle
#       2 make_nanoparticle()
#
# ModuleNotFoundError: No module named 'size'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# This python program will create a nanoparticle that contain 561 atoms. This is the most stable nanoparticle that can be created that contains around-about 500 atoms.

# %% [markdown]
# > Q1: What is the size (diameter) of this nanoparticle (Hint, click on two corner atoms in the ASE GUI that popped up that are as far apart from each other as possible) (Answer: 28.921 Å /2.8921 nm)
#
# >A1: *Double click, then write your answer here. Press Shift+Enter to evaluate the cell*

# %% [markdown]
# Nanoparticles contain **between 13 atoms and 10000 atoms**. What are the diameters of the smallest and largest nanoparticle that you can make with the ``make_nanoparticle()`` function below (this is the same ``make_nanoparticle`` function as in the above line of code).

# %%
make_nanoparticle()

# %% [markdown]
# >Q2: What is the size (diameter) of the **smallest** nanoparticle?
#
# >A2:

# %% [markdown]
# >Q3: What is the size (diameter) of the **largest** nanoparticle?
#
# >A3:

# %% [markdown]
# [Previous Page: 1.2: Using ASE](../Part_1_Getting_Started/2_ASE.ipynb) | [Next Page: 2.2: How do Nanoparticles and Molecules Differ?](./2_Nanoparticles_and_Molecules.ipynb) | [Return to Table of Contents](../Title_Page.ipynb)
