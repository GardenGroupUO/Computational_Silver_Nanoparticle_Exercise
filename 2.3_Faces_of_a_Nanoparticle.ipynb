# %% [markdown]
# # Part 2.3: What are the Faces on the Surface of a Nanoparticle?
#
# The surfaces of nanoparticles are very important, as they determine what nanoparticles look like and can determine some of the properties of those nanoparticles.
#
# There are two types of surfaces that are common to nanoparticles. These are:
#
# - surfaces where the atoms are **arranged as squares** (left), and
# - surfaces where the atoms are **arranged as triangles** (right).
#
# [<img src="https://github.com/GardenGroupUO/Computational_Silver_Nanoparticle_Exercise_Data/blob/main/molecules/square.png?raw=true" width="350"/>](square.png) | [<img src="https://github.com/GardenGroupUO/Computational_Silver_Nanoparticle_Exercise_Data/blob/main/molecules/triangle.png?raw=true" width="350"/>](triangle.png)
# :-------------------------:|:-------------------------:
# **square** | **triangle**

# %% [markdown]
# In this section, **we will examine these different types of surfaces and understand the differences between them.**

# %% [markdown]
# To begin, run the ``faces_of_nanoparticles()`` python code below. This will bring up nanocluster that has a square surface and a triangle surface coloured as show below:
#
# [<img src="https://github.com/GardenGroupUO/Computational_Silver_Nanoparticle_Exercise_Data/blob/main/molecules/square_2.png?raw=true" width="350"/>](molecules/square_2.png) | [<img src="https://github.com/GardenGroupUO/Computational_Silver_Nanoparticle_Exercise_Data/blob/main/molecules/triangle_2.png?raw=true" width="350"/>](triangle_2.png)
# :-------------------------:|:-------------------------:
# **square** | **triangle**

# %%
#@markdown <font color="black" size="+1">←</font><font color="black" size="+1"> First, click the $\blacktriangleright$ play button to install our python programs for this notebook before continuing.</font>

# !echo --------------------------------
# !echo Installing python programs
# !pip install ase==3.22.0 &> /dev/nul
# !echo Completed installing python programs
# !if [ -d Computational_Silver_Nanoparticle_Exercise_Data ]; then rm -Rf Computational_Silver_Nanoparticle_Exercise_Data; fi
# !echo --------------------------------
# !echo Downloading background python scripts from github
# !git clone https://github.com/GardenGroupUO/Computational_Silver_Nanoparticle_Exercise_Data &> /dev/nul
# !echo Completed downloading background python scripts from github
# !echo --------------------------------
# Out:
# --------------------------------
# Installing python programs
# Completed installing python programs
# --------------------------------
# ...
# Completed downloading background python scripts from github
# --------------------------------

# %%
from Computational_Silver_Nanoparticle_Exercise_Data.nanoparticle_faces import faces_of_nanoparticles
from Computational_Silver_Nanoparticle_Exercise_Data.viewer.x3d_viewer import view_x3d
atoms = faces_of_nanoparticles()
view_x3d(atoms,'Exercise_2.3')
# Out:
# <!DOCTYPE>
# <html>
# <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
#     <title>Chemistry Outreach Chemistry Viewer</title>
#     <script type="text/javascript" src="https://www.x3dom.org/download/x3dom.js"> </script>
#     <link rel="stylesheet" type="text/css" href="https://www.x3dom.org/download/x3dom.css"/>
#      <script type="text/javascript" src="https://code.jquery.com/jquery-2.1.0.min.js" ></script>
#
#     <script>
#         //Viewing functions
#
#         function move_view(viewpoint_id)
#         {
#             var viewpoint = document.getElementById(viewpoint_id)
#
#             var viewpoint_id_1 = viewpoint_id+'_1'
#             var viewpoint_id_2 = viewpoint_id+'_2'
#
#             var centerOfRotation = document.getElementById(viewpoint_id_1).getAttribute("centerOfRotation")
#             var last_pressed = document.getElementById(viewpoint_id_1).getAttribute("last_pressed")
#
#             if(last_pressed=='false'){
# ...

# %% [markdown]
# *Square face*

# %% [markdown]
# >Q1: What is the distance between the first nearest neighbour (between a purple and orange atom)?
#
# >A1:

# %% [markdown]
# >Q2: What is the distance between the second nearest neighbour (between a purple and blue atom)?
#
# >A2:

# %% [markdown]
# *Triangle face*

# %% [markdown]
# >Q3: What is the distance between the first nearest neighbour (between a purple and orange atom)?
#
# >A3:

# %% [markdown]
# >Q4: What is the distance between the second nearest neighbour (between a purple and green atom)?
#
# >A4:

# %% [markdown]
# Next, we will count the **number of neighbouring atoms** surrounding the purple atoms on the square and triangle face. Notice that some of the atoms that neighbour the purple atoms are found beneath the surface.
#
# To do this, run the ``number_of_neighbouring_atoms`` python program below. This will bring up the same nanoparticle we have been looking at, but with just the purple and orange atoms coloured in. Neighbouring atoms beneath the surface that neighbour the purple atom have also been coloured in.

# %%
from Computational_Silver_Nanoparticle_Exercise_Data.nanoparticle_faces import number_of_neighbouring_atoms
from Computational_Silver_Nanoparticle_Exercise_Data.viewer.x3d_viewer import view_x3d
atoms = number_of_neighbouring_atoms()
view_x3d(atoms,'Exercise_2.3')
# Out:
# <!DOCTYPE>
# <html>
# <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
#     <title>Chemistry Outreach Chemistry Viewer</title>
#     <script type="text/javascript" src="https://www.x3dom.org/download/x3dom.js"> </script>
#     <link rel="stylesheet" type="text/css" href="https://www.x3dom.org/download/x3dom.css"/>
#      <script type="text/javascript" src="https://code.jquery.com/jquery-2.1.0.min.js" ></script>
#
#     <script>
#         //Viewing functions
#
#         function move_view(viewpoint_id)
#         {
#             var viewpoint = document.getElementById(viewpoint_id)
#
#             var viewpoint_id_1 = viewpoint_id+'_1'
#             var viewpoint_id_2 = viewpoint_id+'_2'
#
#             var centerOfRotation = document.getElementById(viewpoint_id_1).getAttribute("centerOfRotation")
#             var last_pressed = document.getElementById(viewpoint_id_1).getAttribute("last_pressed")
#
#             if(last_pressed=='false'){
# ...

# %% [markdown]
# Answer the following questions:

# %% [markdown]
# *Square face*

# %% [markdown]
# >Q5: How many atoms neighbour the purple atom on the square face?
#
# >A5:

# %% [markdown]
# *Triangle face*

# %% [markdown]
# >Q6: How many atoms neighbour the purple atom on the triangle face?
#
# >A6:

# %% [markdown]
# Lets compare this with the number of neighbour that would surround an atom in the bulk (i.e. in the middle of the nanoparticle). Run the ``number_of_neighbouring_atoms_in_middle_of_nanoparticle()`` python code below. This will show a nanoparticle with a purple atom and neighbouring atoms coloured in orange. You may need to delete some of the silver atoms in order to look at these coloured atoms better

# %%
from Computational_Silver_Nanoparticle_Exercise_Data.nanoparticle_faces import number_of_neighbouring_atoms_in_middle_of_nanoparticle
from Computational_Silver_Nanoparticle_Exercise_Data.viewer.x3d_viewer import view_x3d
atoms = number_of_neighbouring_atoms_in_middle_of_nanoparticle()
view_x3d(atoms,'Exercise_2.3')
# Out:
# <!DOCTYPE>
# <html>
# <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
#     <title>Chemistry Outreach Chemistry Viewer</title>
#     <script type="text/javascript" src="https://www.x3dom.org/download/x3dom.js"> </script>
#     <link rel="stylesheet" type="text/css" href="https://www.x3dom.org/download/x3dom.css"/>
#      <script type="text/javascript" src="https://code.jquery.com/jquery-2.1.0.min.js" ></script>
#
#     <script>
#         //Viewing functions
#
#         function move_view(viewpoint_id)
#         {
#             var viewpoint = document.getElementById(viewpoint_id)
#
#             var viewpoint_id_1 = viewpoint_id+'_1'
#             var viewpoint_id_2 = viewpoint_id+'_2'
#
#             var centerOfRotation = document.getElementById(viewpoint_id_1).getAttribute("centerOfRotation")
#             var last_pressed = document.getElementById(viewpoint_id_1).getAttribute("last_pressed")
#
#             if(last_pressed=='false'){
# ...

# %% [markdown]
# >Q7: How many atoms neighbour the purple atom in the bulk of the nanoparticle?
#
# >A7:

# %% [markdown]
# [Previous Page: 2.2: How do Nanoparticles and Molecules Differ?](./2_Nanoparticles_and_Molecules.ipynb) | [Next Page: 2.4: How are these Faces related to Energetics and Stability?](./4_Faces_related_to_Energy_and_Stability.ipynb) | [Return to Table of Contents](../Title_Page.ipynb)
