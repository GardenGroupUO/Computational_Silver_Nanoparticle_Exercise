# %% [markdown]
# # Part 1.1: Introduction to Python3 and Jupyter
#
# In this exercise you will be using a computer programming language called Python3. Python3 is a programming language used for many applications, including scientific research. A programming language is used to instruct the computer to run a set of instructions (a script) to produce outputs.
#
# Python programs are often run through a computer, but for this exercise you will be run Python3 through JupyterLab. JupyterLab is a web-based interactive development environment for running code within a notebook that contains notes and instructions.
#
# There are a few things to know about using JupyterLab before we get going
#
# ## Jupyter Notebooks
#
# Today we will be using Jupyter Notebooks to learn about silver nanoparticles using computational chemistry. What you are reading right now is a jupyter notebook. It is a notebook that you can write notes in, as well as run python code in. We are running our notebooks in Google Colabs. Think of these notebooks like a word document, you can read them and you can write your own notes on them. We will be writing on our notebooks to answer questions.
#
# Questions and places to answer your questions will look like this:
#
# >Q1: This is a question
#
# >A1: Write your answer in here
#
# To write an answert in a notebook, double click on the place that you want to write to. Try this below, try to write something to the question below:

# %% [markdown]
# >Q2: What is the weather like today?
#
# >A2: *Write your answer here*

# %% [markdown]
# ## A Prerequisite To-Do Before we get into our Lesson
#
# To begin, we need to install some python programs into our workspace and download some python scripts that we have written for this lesson to our Google Colab. Click the $\blacktriangleright$ below to download our files.

# %%
#@markdown <font color="black" size="+1">←</font><font color="black" size="+1"> Click the $\blacktriangleright$ play button to load our files</font>

# !echo --------------------------------
# !echo Installing python programs
# !pip install ase==3.22.0 &> /dev/nul
# !echo Completed installing python programs
# !if [ -d Computational_Silver_Nanoparticle_Exercise_Data ]; then rm -Rf Computational_Silver_Nanoparticle_Exercise_Data; fi
# !echo --------------------------------
# !echo Downloading background python scripts from github
# !git clone https://github.com/GardenGroupUO/Computational_Silver_Nanoparticle_Exercise_Data &> /dev/nul
# !echo Completed downloading background python scripts from github
# !echo --------------------------------

# %% [markdown]
# When the files have been loaded, you will see the $\blacktriangleright$ play button be replaced with a ✔️ tick symbol.
#
# You will be reminded to do this at the start of each notebook.
#
# You dont need to wait for this $\blacktriangleright$ play button be replaced with a ✔️ tick, you can continue to read through this notebook. It should be quick anyhow. If you have any problems with the code, check first to see if the ✔️ tick has appeared.

# %% [markdown]
# ## Running Python code in our Notebook
#
# We will now look at how to run python code in our notebook. If you want to run a line of Python3 code, click on that line of code and press the $\blacktriangleright$ button next to this line of code in Google Colab.
#
# Try this on the line of code below. Hover your mouse over the line of code below and click on the the $\blacktriangleright$ play button when it appears to run our code below:

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# You will see that it has printed the text `Hello World` in a `typeset` font.

# %% [markdown]
# You can also run this notebook in full from start to end. To do this, at the top of the notebook click `Runtime -> Run all`. This will run every code box in the notebook. If you want to restart the notebook, at the top of the notebook click `Runtime -> Restart and run all`. This may prompt you if you want to restart the notebook. Click `Yes` to restart the script.
#
# **Try this and watch the other code boxes be performed consecutively**. You can press the $\rm{\blacksquare}$ button in binder or google colab at any time to stop the notebook from running the notebook's code.

# %% [markdown]
# ## We have finished Part 1.1!
#
# That was quite a bit of new stuff that we have just learnt! We will be doing a lot of this over and over, so don't worry if you don't feel like you are a bit lost at this point.
#
# Once you get to the end of each section, go back to your google drive and click on the next notebook. We will next be looking at some of the python programs we will be using in **1.2_Intro_to_ASE.ipynb**
